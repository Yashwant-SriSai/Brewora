# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashwant-SriSai/Brewora/blob/main/Shakespher's_like_text_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Imports
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Embedding
from tensorflow.keras.optimizers import RMSprop
import random
import sys

# %%
#Load he Shakesphere's Dataset
print("Downloading Sakesphere's Data....")
path = tf.keras.utils.get_file('shakespeare.txt',
    origin='https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt')
with open(path,encoding="utf-8") as f:
  text=f.read().lower() # why lower? so that model won't have to remember that both "a" and "A" or same.
# lets take first 200,000 characters for our vocabulary
text=text[:200000]
print(f'Corpus Length:{len(text)}')
# Out:
# Downloading Sakesphere's Data....
# Corpus Length:200000

# %%
#Map characters to integers
# 1st we need to sort the characters to get unique characters
chars=sorted(list(set(text)))
print(f'total no.of unique characters:{len(chars)}')
# lets map these unique characters
char_indices={c:i for i,c in enumerate(chars)}
indices_char={i:c for i,c in enumerate(chars)}
# Out:
# total no.of unique characters:37

# %%
# now we create a sequence from the text as we ae using lstms it learns from sequences to get vast traing data we use sliding windows wth a step of 3-5
# Here with creating sequence we are nothing but creating two arrays says for every let day 40 characters we need to fnd 41th character so we creating a "sentence[]" which contains characters of certain length say 40 and "next_char[]" will contain 41th character we continue this throught all the text with a step
max_len=40
step=3
sentences=[]
next_char=[]
for i in range(0,len(text)-max_len,3):
  sentences.append(text[i:i+max_len])
  next_char.append(text[i+max_len])
print(f'Number of training Sequences:{len(sentences)}')
# Out:
# Number of training Sequences:66654

# %%
# Now we will do integer encoding meaning we are converting
print("Integer Ecoding data for the embedding layer...")
# Now we create x,y where x is a 2d array of dimensions len(sentences),max_len i.e (66654,40) and y of shape 66654.
# These x,y are all zeros later we change the specific characters position "0" to its integer ID
x=np.zeros((len(sentences),max_len),dtype=np.int32)
y=np.zeros((len(sentences),),dtype=np.int32)

for i,sentence in enumerate(sentences):
  for t,char in enumerate(sentence):
    x[i,t]=char_indices[char]
  y[i]=char_indices[next_char[i]]
print(f'Id_s of x: {x}')
print(f'Target values Id_s: {y}')
# Out:
# Integer Ecoding data for the embedding layer...
# Id_s of x: [[16 19 28 ... 16 31 28]
#  [29 30  1 ... 30 18 15]
#  [13 19 30 ... 28  5  1]
#  ...
#  [15 24  1 ... 15 15 10]
#  [30 18 25 ...  0  0 13]
#  [31  1 18 ... 22 11 28]]
# Target values Id_s: [30 28 18 ...  0 22 15]

# %%
# Lets build our Emmbedding+LSTM Model
print("Building Model...")
model=Sequential([
    # in emdeddings layer we have teo parameters input_dim and out_Dim .
    # Here input_dim=vocabulary size i.e length(unique chars) and out_dim are the size of vector we want to compress into
    Embedding(input_dim=len(chars),output_dim=32),
    LSTM(128),
    Dense(len(chars),activation="softmax")
])
model.compile(loss="sparse_categorical_crossentropy",optimizer=RMSprop(learning_rate=0.01))
#categorical_crossentropy: Expects your target $Y$ to be a One-Hot Array. It expects to see something like [0, 0, 0, 1, 0, 0] to know the 4th character is the correct answer.
#sparse_categorical_crossentropy: Expects your target $Y$ to just be a Single Integer. It expects to see the number 3.
# Out:
# Building Model...

# %%
# Now lets Create a sample function to adjust the randomness of the predictions
def sample(preds,temp):
  preds=np.asarray(preds).astype("float64")
  preds=np.log(preds+ 1e-7)/temp # here we are chaging our values into log divides by temp to get values that have some significant difference between them
                                 # so that model won't go into loops selecting/predicting the same char with highest probbility
                                 #np.log(preds): We take the raw percentages (0.0 to 1.0) and convert them back into "logits" (raw mathematical scores).
                                 # temperature: We divide those scores by our temperature setting.
                                 # If Temp is low (0.2), it stretches the scores apart. The #1 likely character becomes massively dominant.
                                 # If Temp is high (1.5), it squishes the scores together. The #1 character and the #5 character suddenly look very similar.
                                 # we use 1e-7 to prevent getting value 0 as log(0) is mathematically undefined
  exp_preds=np.exp(preds) #Here we change he log values into prbabilities (float values) to choose the one randomly
  preds=exp_preds/np.sum(exp_preds)

  probas= np.random.multinomial(1,preds,1)
  return np.argmax(probas)

# %%
epochs = 50          # Increased to 50 for actual coherent text
batch_size = 128
generation_temp = 0.5 # Set your manual temperature here (0.4 - 0.6 is best)

print(f"Starting training for {epochs} epochs...")

for epoch in range(epochs):
    print(f"\n--- Epoch {epoch + 1} ---")

    # Train for one epoch
    model.fit(x, y, batch_size=batch_size, epochs=1)

    # Pick a random starting seed
    start_index = random.randint(0, len(text) - max_len - 1)
    sentence = text[start_index: start_index + max_len]

    print(f"\n--- Generating with Temperature: {generation_temp} ---")
    print(f'Seed: "{sentence}"\n')

    generated = sentence
    sys.stdout.write(generated)

    # Generate 100 characters
    for i in range(100):
        # Format the input for the Embedding layer
        x_pred = np.zeros((1, max_len), dtype=np.int32)
        for t, char in enumerate(sentence):
            x_pred[0, t] = char_indices[char]

        # Predict, Sample, and Decode
        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, generation_temp)
        next_char = indices_char[next_index]

        # Slide the window
        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print("\n") # Add a final newline for clean formatting
# Out:
# Starting training for 50 epochs...
#
# --- Epoch 1 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 58s 112ms/step - loss: 1.3491
#
# --- Generating with Temperature: 0.5 ---
# Seed: " groan and drop: then know me not,
# lest "
#
#  groan and drop: then know me not,
# lest your patient that that say he wounds,
# the suil with all the consul, let than partal
# and of him bonne
#
#
# --- Epoch 2 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 108ms/step - loss: 1.3482
#
# --- Generating with Temperature: 0.5 ---
# Seed: "me
# had circumvention? 'tis not four days"
#
# me
# had circumvention? 'tis not four dayse all to the people
# it show the cannot most bechepter his hand,
# that be as the senate once the denie
#
#
# --- Epoch 3 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 110ms/step - loss: 1.3716
#
# --- Generating with Temperature: 0.5 ---
# Seed: "them by the other lose,
# that they combin"
#
# them by the other lose,
# that they combined with the with him.
#
# coriolanus:
# i will the gates hath be some to you to the people,
# stabl done th
#
#
# --- Epoch 4 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 109ms/step - loss: 1.3735
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ame he; where he did
# run reeking o'er th"
#
# ame he; where he did
# run reeking o'er the rome, and the people
# the gods beate a prithe of the city are poince,
# and the murd of the madge the
#
#
# --- Epoch 5 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 108ms/step - loss: 1.3643
#
# --- Generating with Temperature: 0.5 ---
# Seed: "or the best; and
# though we willingly con"
#
# or the best; and
# though we willingly condemning of the mut
# to the sword hered your consul commanded
# than the consul be the mother, and they
#
#
# --- Epoch 6 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 108ms/step - loss: 1.3791
#
# --- Generating with Temperature: 0.5 ---
# Seed: "
# the harm of unscann'd swiftness, will t"
#
#
# the harm of unscann'd swiftness, will the fourthem.
#
# cominius:
# he was have die them in them, and i have not have and tell his perport,
# to a
#
#
# --- Epoch 7 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 109ms/step - loss: 1.3981
#
# --- Generating with Temperature: 0.5 ---
# Seed: "re than his singularity, he goes
# upon th"
#
# re than his singularity, he goes
# upon the voices him since for you wounded
# his poive the volsces his deed of the commord
# with his marcius.
#
#
#
#
# --- Epoch 8 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 109ms/step - loss: 1.3868
#
# --- Generating with Temperature: 0.5 ---
# Seed: "te hath
# another, his wife another; and, "
#
# te hath
# another, his wife another; and, well are more of the cate a marcius,
# what we have beling than i dook of as the porter,
# that what the
#
#
# --- Epoch 9 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 58s 111ms/step - loss: 1.3965
#
# --- Generating with Temperature: 0.5 ---
# Seed: "meanest house in rome, so far my son--
# t"
#
# meanest house in rome, so far my son--
# the cause thee to the senate of a trather
# but ement to the good to be stay our comminity:
# which we ha
#
#
# --- Epoch 10 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 108ms/step - loss: 1.4118
#
# --- Generating with Temperature: 0.5 ---
# Seed: "re your own eyes and ears?
#
# all conspira"
#
# re your own eyes and ears?
#
# all conspirace, with his has propse the sword,
# sir, the compans against the son, and in the peace,
# and the sunce
#
#
# --- Epoch 11 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 59s 113ms/step - loss: 1.4025
#
# --- Generating with Temperature: 0.5 ---
# Seed: "hbours.
#
# brutus:
# god-den to you all, god"
#
# hbours.
#
# brutus:
# god-den to you all, gods my porter and in the menen
# to more power of the peopleper, when you
# the people soldies: let us wit
#
#
# --- Epoch 12 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 107ms/step - loss: 1.4123
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ry service.
#
# first servingman:
# wine, win"
#
# ry service.
#
# first servingman:
# wine, wine here, i was to being the wars
# with on ever be stard med the conserved me the below
# he would he wou
#
#
# --- Epoch 13 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 108ms/step - loss: 1.4119
#
# --- Generating with Temperature: 0.5 ---
# Seed: " sacrifice,
# embarquements all of fury, s"
#
#  sacrifice,
# embarquements all of fury, show'll all them.
#
# sicinius:
# the people, prever him and consul himself:
# you ward. give your him he ha
#
#
# --- Epoch 14 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 109ms/step - loss: 1.4249
#
# --- Generating with Temperature: 0.5 ---
# Seed: " sort, may be said to
# be a ravisher, so "
#
#  sort, may be said to
# be a ravisher, so they
# we them son all the thing thee.
#
# menenius:
# sir.
#
# second meneen:
# why, he would i should hear you
#
#
# --- Epoch 15 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 55s 105ms/step - loss: 1.4419
#
# --- Generating with Temperature: 0.5 ---
# Seed: "cond murderer:
# nor you, as we are, loyal"
#
# cond murderer:
# nor you, as we are, loyal the gress of thy
# sunn! thought whet whose with the suf them was in
# the gress, be cannot be sors, th
#
#
# --- Epoch 16 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 107ms/step - loss: 1.4385
#
# --- Generating with Temperature: 0.5 ---
# Seed: "s 'twas used
# sometime in greece,--
#
# mene"
#
# s 'twas used
# sometime in greece,--
#
# menenius:
# the other before by
# it is for you are she shall i prither hour doubler.
#
# menenius:
# i have not
#
#
# --- Epoch 17 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 109ms/step - loss: 1.4523
#
# --- Generating with Temperature: 0.5 ---
# Seed: "aunts i often have endured.
# i had rather"
#
# aunts i often have endured.
# i had rather the our mene the kings thanks,
# the senate to the fie: the honours the love
# have a tribunes be so wi
#
#
# --- Epoch 18 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 109ms/step - loss: 1.4693
#
# --- Generating with Temperature: 0.5 ---
# Seed: "and to be partly proud; which he
# is, eve"
#
# and to be partly proud; which he
# is, even strange to the that make the come
# to the gods hadbent make my so that their
# that may to may should
#
#
# --- Epoch 19 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 107ms/step - loss: 1.4930
#
# --- Generating with Temperature: 0.5 ---
# Seed: "on, as thou hast said
# my praises made th"
#
# on, as thou hast said
# my praises made the the gods to do where not
# for worth his truth of which shall wounds
# a voice to be them so bass of t
#
#
# --- Epoch 20 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 108ms/step - loss: 1.5120
#
# --- Generating with Temperature: 0.5 ---
# Seed: "baited
# with one that wants her wits?
#
# vo"
#
# baited
# with one that wants her wits?
#
# volumnia:
# as is the common the made with the made maketger
# with all blood with the market--
#
# brutus:
# a
#
#
# --- Epoch 21 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 109ms/step - loss: 1.5173
#
# --- Generating with Temperature: 0.5 ---
# Seed: "
#
# second murderer:
# in the duke of glouce"
#
#
#
# second murderer:
# in the duke of glouces i does a post him they
# and thy hath your coriolist that the senater,
# that i can more heart keep th
#
#
# --- Epoch 22 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 108ms/step - loss: 1.5006
#
# --- Generating with Temperature: 0.5 ---
# Seed: "e look'd
# for no less spoil than glory,--"
#
# e look'd
# for no less spoil than glory,--
#
# second ander:
# and were the granter to be things and a ware to the so destons,
# we have stand in the
#
#
# --- Epoch 23 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 109ms/step - loss: 1.5077
#
# --- Generating with Temperature: 0.5 ---
# Seed: "york and edward wept,
# to hear the piteou"
#
# york and edward wept,
# to hear the piteous, why hath you, i were
# the gatuse the more hery and in with a good heart
# to his venge to the cane p
#
#
# --- Epoch 24 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 59s 113ms/step - loss: 1.5161
#
# --- Generating with Temperature: 0.5 ---
# Seed: " all afraid?
# alas, i blame you not; for "
#
#  all afraid?
# alas, i blame you not; for you, if we will done i wount;
# and i like rume with his as but his in the with himbest.
# i have fill m
#
#
# --- Epoch 25 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 58s 110ms/step - loss: 1.5369
#
# --- Generating with Temperature: 0.5 ---
# Seed: "t,
# and take deep traitors for thy deares"
#
# t,
# and take deep traitors for thy deares on the deed
# as you a to the we was makes to the merned with dield
# the renone of hear well leave the
#
#
# --- Epoch 26 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 109ms/step - loss: 1.5332
#
# --- Generating with Temperature: 0.5 ---
# Seed: "stream o' the people;
# and this shall see"
#
# stream o' the people;
# and this shall seeply to him here the people!
#
# meneriman:
# the companing thee is the compore my of the boide
# of you her
#
#
# --- Epoch 27 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 109ms/step - loss: 1.5341
#
# --- Generating with Temperature: 0.5 ---
# Seed: "e, god take king edward to his mercy,
# an"
#
# e, god take king edward to his mercy,
# and he she the percorpers; and corioly fallight
# the more beher his the gods the senate the man so have
#
#
# --- Epoch 28 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 58s 111ms/step - loss: 1.5370
#
# --- Generating with Temperature: 0.5 ---
# Seed: "oices: now you have left
# your voices,
# i "
#
# oices: now you have left
# your voices,
# i am thy sheare that stare; you have should are.
#
# coriolanus:
# coriolanus, to the would all the man wit
#
#
# --- Epoch 29 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 108ms/step - loss: 1.5317
#
# --- Generating with Temperature: 0.5 ---
# Seed: "
# your offices?
# you being their mouths, w"
#
#
# your offices?
# you being their mouths, which the patient a loves his a nobeent
# to the mans, been when your from he deside lady
# o man the lon
#
#
# --- Epoch 30 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 59s 112ms/step - loss: 1.5405
#
# --- Generating with Temperature: 0.5 ---
# Seed: " of some death more long in
# spectatorshi"
#
#  of some death more long in
# spectatorshipe to slave of the peoplest to horse,
# i were to the poino little me too a patient
# in ask the enemied
#
#
# --- Epoch 31 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 109ms/step - loss: 1.5187
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ham, take heed of yonder dog!
# look, when"
#
# ham, take heed of yonder dog!
# look, when i have men them partient with their mistirate,
# then be here; in thee of him, in.
#
# menenius:
# he repe
#
#
# --- Epoch 32 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 109ms/step - loss: 1.5198
#
# --- Generating with Temperature: 0.5 ---
# Seed: "e, but one of better nature.
#
# lady anne:"
#
# e, but one of better nature.
#
# lady anne:
# and not unnot to know a gether better to his know sonce,
# you the voices and of the conseanced deser
#
#
# --- Epoch 33 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 109ms/step - loss: 1.5077
#
# --- Generating with Temperature: 0.5 ---
# Seed: " are thine.
# and if thy poor devoted supp"
#
#  are thine.
# and if thy poor devoted suppinent in the broke with in thee;
# where the cannot the marcius, where should we wall
# will the murther
#
#
# --- Epoch 34 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 108ms/step - loss: 1.4944
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ty of your general.
#
# second senator:
# how"
#
# ty of your general.
#
# second senator:
# how brave, but your may hear his noble will not
# the kingerts by the prophe your poor defend
# that the di
#
#
# --- Epoch 35 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 110ms/step - loss: 1.5052
#
# --- Generating with Temperature: 0.5 ---
# Seed: "done thee wrong?
# or thee? or thee? or an"
#
# done thee wrong?
# or thee? or thee? or and by you have marcius,
# that and the resh me tonce of the loke that was in they
# shall the slain that
#
#
# --- Epoch 36 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 107ms/step - loss: 1.4978
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ms with fins of lead
# and hews down oaks "
#
# ms with fins of lead
# and hews down oaks and neit one to honour:
# and them he should to the most so how pray,
# the met in my husband them to do
#
#
# --- Epoch 37 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 108ms/step - loss: 1.5029
#
# --- Generating with Temperature: 0.5 ---
# Seed: "pend my
# malice in my breath. meeting two"
#
# pend my
# malice in my breath. meeting tworrs be what have
# the matter, and partice'd for the suping
# and me are my for a mour to my for mine en
#
#
# --- Epoch 38 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 60s 116ms/step - loss: 1.5294
#
# --- Generating with Temperature: 0.5 ---
# Seed: "n, the husband and the father tearing
# hi"
#
# n, the husband and the father tearing
# him it, your braw?
#
# cominius:
# so have his praster we are the cannot perce to make and
# the be make me,
#
#
# --- Epoch 39 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 108ms/step - loss: 1.5086
#
# --- Generating with Temperature: 0.5 ---
# Seed: "whereto we are bound? alack, or we must "
#
# whereto we are bound? alack, or we must for that to must shame, that they live
# that have peace.
#
# menenius:
# the good for the people, and by w
#
#
# --- Epoch 40 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 109ms/step - loss: 1.5138
#
# --- Generating with Temperature: 0.5 ---
# Seed: "e atonement
# betwixt the duke of gloucest"
#
# e atonement
# betwixt the duke of gloucester:
# and he will must strike the prifes, the will better
# the endreice, the mother to hust to the prit
#
#
# --- Epoch 41 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 107ms/step - loss: 1.5383
#
# --- Generating with Temperature: 0.5 ---
# Seed: "irst,
# which you do live upon; and fit it"
#
# irst,
# which you do live upon; and fit it to the forgues and stoke and
# since the cot, the peaces it the souns:
# may the very sore the vissues
#
#
# --- Epoch 42 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 57s 110ms/step - loss: 1.5487
#
# --- Generating with Temperature: 0.5 ---
# Seed: "woman in this humour won?
# i'll have her;"
#
# woman in this humour won?
# i'll have her; i have most of rome the people,
# i pride to the father wounded in they senate
# the cannot reast me.
#
#
#
#
# --- Epoch 43 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 108ms/step - loss: 1.5199
#
# --- Generating with Temperature: 0.5 ---
# Seed: "speech: he did not mock us.
#
# second citi"
#
# speech: he did not mock us.
#
# second citizen:
# the to this the seeat compane, in that this compt
# in a parsel thy dene of the provent,
# who i da
#
#
# --- Epoch 44 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 107ms/step - loss: 1.5413
#
# --- Generating with Temperature: 0.5 ---
# Seed: "tizens:
# you so remain.
#
# menenius:
# and so"
#
# tizens:
# you so remain.
#
# menenius:
# and so women humblery of peace my gown who that thou?
#
# mene come, and the bring those the soud spaint
# be s
#
#
# --- Epoch 45 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 107ms/step - loss: 1.5578
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ers.
#
# gloucester:
# say that i slew them n"
#
# ers.
#
# gloucester:
# say that i slew them not so born will.
#
# first servingman:
# the strenter how here of the gods!
#
# menenius:
# skeak. we would he
#
#
# --- Epoch 46 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 108ms/step - loss: 1.5538
#
# --- Generating with Temperature: 0.5 ---
# Seed: "loudy wrath
# hath in eternal darkness fol"
#
# loudy wrath
# hath in eternal darkness follow and the nature
# of the vaide him as and like.
#
# menenius:
# he hurt as a can begg'
# thou ture the wit
#
#
# --- Epoch 47 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 107ms/step - loss: 1.5530
#
# --- Generating with Temperature: 0.5 ---
# Seed: "me, like the virtues
# which our divines l"
#
# me, like the virtues
# which our divines leave is his god wind sench, and their worthy cannot the offrone that nay,
# the bears it sirral'd he w
#
#
# --- Epoch 48 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 58s 111ms/step - loss: 1.5533
#
# --- Generating with Temperature: 0.5 ---
# Seed: "e seen me.
#
# menenius:
# down with that swo"
#
# e seen me.
#
# menenius:
# down with that swords abone out in their make
# him his common' of the at the cominius bear
# his by the pecresting a thou
#
#
# --- Epoch 49 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 108ms/step - loss: 1.5587
#
# --- Generating with Temperature: 0.5 ---
# Seed: "war hath smooth'd his wrinkled front;
# an"
#
# war hath smooth'd his wrinkled front;
# and that i am were we not partion with in hearts
# than friends so a prover not to the parry
# than lial m
#
#
# --- Epoch 50 ---
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 56s 108ms/step - loss: 1.5538
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ction: therefore shall he die,
# and i'll "
#
# ction: therefore shall he die,
# and i'll be cannot hower the gloud in be in noth
# on the gods the stake a cane of service it cannot the statch
